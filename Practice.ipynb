# %%
import pandas as pd

# %%
us_baby = pd.read_csv('./Exercise Files/us_baby_names.csv')

# %%
us_baby
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
us_baby.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %%
us_baby['Year']
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1825428    2014
# 1825429    2014
# 1825430    2014
# 1825431    2014
# 1825432    2014
# Name: Year, Length: 1825433, dtype: int64

# %%
us_baby['Year'] == 2014
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1825428     True
# 1825429     True
# 1825430     True
# 1825431     True
# 1825432     True
# Name: Year, Length: 1825433, dtype: bool

# %%
us_baby.loc[lambda us_baby: us_baby['Year'] == 2014]
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
us_baby_2014 = us_baby.loc[us_baby['Year']==2014,:]

# %%
sorted_us_baby_2014 = us_baby_2014.sort_values('Count',ascending=False)

# %%
sorted_us_baby_2014.head(5)
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
sorted_us_baby_2014.iloc[0:5]
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
state_babies = pd.read_csv('./Exercise Files/state_baby_names.csv')

# %%
state_babies.head()
# Out:
#    Id      Name  Year Gender State  Count
# 0   1      Mary  1910      F    AK     14
# 1   2     Annie  1910      F    AK     12
# 2   3      Anna  1910      F    AK     10
# 3   4  Margaret  1910      F    AK      8
# 4   5     Helen  1910      F    AK      7

# %%
state_babies['State']
# Out:
# 0          AK
# 1          AK
# 2          AK
# 3          AK
# 4          AK
#            ..
# 5647421    WY
# 5647422    WY
# 5647423    WY
# 5647424    WY
# 5647425    WY
# Name: State, Length: 5647426, dtype: object

# %%
state_babies['State'].unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
state_babies.loc[state_babies['State']=='CA',:]
# Out:
#             Id      Name  Year Gender State  Count
# 356017  356018      Mary  1910      F    CA    295
# 356018  356019     Helen  1910      F    CA    239
# 356019  356020   Dorothy  1910      F    CA    220
# 356020  356021  Margaret  1910      F    CA    163
# 356021  356022   Frances  1910      F    CA    134
# ...        ...       ...   ...    ...   ...    ...
# 710225  710226    Zakary  2014      M    CA      5
# 710226  710227   Zealand  2014      M    CA      5
# 710227  710228      Ziad  2014      M    CA      5
# 710228  710229    Zidane  2014      M    CA      5
# 710229  710230     Ziyad  2014      M    CA      5
#
# [354213 rows x 6 columns]

# %%
state_babies.loc[state_babies['Year']==2014 and state_babies['State'] =='CA',:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xy/bxjd55nx30x56z6wsgxpjrxc0000gn/T/ipykernel_29819/958758395.py in <module>
# ----> 1 state_babies.loc[state_babies['Year']==2014 and state_babies['State'] =='CA',:]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
state_babies_2014 = state_babies.loc[state_babies['Year']==2014,:]

# %%
state_babies_2014
# Out:
#               Id      Name  Year Gender State  Count
# 13522      13523      Emma  2014      F    AK     50
# 13523      13524    Olivia  2014      F    AK     47
# 13524      13525    Sophia  2014      F    AK     43
# 13525      13526    Aurora  2014      F    AK     35
# 13526      13527  Isabella  2014      F    AK     33
# ...          ...       ...   ...    ...   ...    ...
# 5647421  5647422      Seth  2014      M    WY      5
# 5647422  5647423   Spencer  2014      M    WY      5
# 5647423  5647424      Tyce  2014      M    WY      5
# 5647424  5647425    Victor  2014      M    WY      5
# 5647425  5647426    Waylon  2014      M    WY      5
#
# [94148 rows x 6 columns]

# %%
state_babies_CA_2014 = state_babies_2014.loc[state_babies_2014["State"] == "CA",:]

# %%
state_babies_CA_2014
# Out:
#             Id      Name  Year Gender State  Count
# 561495  561496    Sophia  2014      F    CA   3162
# 561496  561497  Isabella  2014      F    CA   2705
# 561497  561498      Emma  2014      F    CA   2662
# 561498  561499       Mia  2014      F    CA   2627
# 561499  561500    Olivia  2014      F    CA   2407
# ...        ...       ...   ...    ...   ...    ...
# 710225  710226    Zakary  2014      M    CA      5
# 710226  710227   Zealand  2014      M    CA      5
# 710227  710228      Ziad  2014      M    CA      5
# 710228  710229    Zidane  2014      M    CA      5
# 710229  710230     Ziyad  2014      M    CA      5
#
# [6903 rows x 6 columns]

# %%
sorted_CA_2014 = state_babies_CA_2014.sort_values("Count", ascending=False)

# %%
sorted_CA_2014.iloc[0:5]
# Out:
#             Id      Name  Year Gender State  Count
# 561495  561496    Sophia  2014      F    CA   3162
# 707311  707312      Noah  2014      M    CA   2761
# 561496  561497  Isabella  2014      F    CA   2705
# 707312  707313     Jacob  2014      M    CA   2692
# 561497  561498      Emma  2014      F    CA   2662

# %%
ca_babies = state_babies.loc[state_babies["State"]=="CA"]

# %%
ca_babies
# Out:
#             Id      Name  Year Gender State  Count
# 356017  356018      Mary  1910      F    CA    295
# 356018  356019     Helen  1910      F    CA    239
# 356019  356020   Dorothy  1910      F    CA    220
# 356020  356021  Margaret  1910      F    CA    163
# 356021  356022   Frances  1910      F    CA    134
# ...        ...       ...   ...    ...   ...    ...
# 710225  710226    Zakary  2014      M    CA      5
# 710226  710227   Zealand  2014      M    CA      5
# 710227  710228      Ziad  2014      M    CA      5
# 710228  710229    Zidane  2014      M    CA      5
# 710229  710230     Ziyad  2014      M    CA      5
#
# [354213 rows x 6 columns]

# %%
group_ca_babies = ca_babies.groupby(['Year', 'Gender'], axis=0)

# %%
group_ca_babies.mean()
# Out:
#                    Id      Count
# Year Gender
# 1910 F       356134.0  25.536481
#      M       565544.5  24.723077
# 1911 F       356376.0  26.302789
#      M       565680.5  23.816901
# 1912 F       356653.0  32.353135
# ...               ...        ...
# 2012 M       702968.5  79.102617
# 2013 F       559520.0  51.655024
#      M       705866.0  78.173296
# 2014 F       563487.5  52.101657
#      M       708771.0  78.444330
#
# [210 rows x 2 columns]

# %%
def popular(s):
    return s.iloc[0]

# %%
ca_group = ca_babies.sort_values("Count", ascending=False).groupby(['Year', 'Gender'], axis=0).agg([popular])

# %%
ca_group
# Out:
#                  Id    Name State  Count
# Year Gender
# 1910 F       356018    Mary    CA    295
#      M       565480    John    CA    237
# 1911 F       356251    Mary    CA    390
#      M       565610    John    CA    214
# 1912 F       356502    Mary    CA    534
# ...             ...     ...   ...    ...
# 2012 M       701517   Jacob    CA   2971
# 2013 F       557545  Sophia    CA   3451
#      M       704421   Jacob    CA   2879
# 2014 F       561496  Sophia    CA   3162
#      M       707312    Noah    CA   2761
#
# [210 rows x 4 columns]

# %%
ca_group = ca_babies.sort_values("Count", ascending=False).groupby(['Year', 'Gender'], axis=0).agg("sum")
ca_group
# Out:
#                      Id   Count
# Year Gender
# 1910 F         82979222    5950
#      M         73520785    3214
# 1911 F         89450376    6602
#      M         80326631    3382
# 1912 F        108065859    9803
# ...                 ...     ...
# 2012 M       2041420524  229714
# 2013 F       2210663520  204089
#      M       2040658606  225999
# 2014 F       2244934200  207573
#      M       2068902549  228979
#
# [210 rows x 2 columns]

# %%
myname = us_baby.loc[us_baby['Name'] == 'Viral',:]

# %%
myname
# Out:
#               Id   Name  Year Gender  Count
# 900293    900294  Viral  1981      M      8
# 920560    920561  Viral  1982      M      7
# 1022095  1022096  Viral  1987      M      6
# 1043586  1043587  Viral  1988      M      7
# 1066422  1066423  Viral  1989      M      8
# 1092752  1092753  Viral  1990      M      6
# 1144628  1144629  Viral  1992      M      5
# 1170575  1170576  Viral  1993      M      5
# 1195147  1195148  Viral  1994      M      6
# 1276042  1276043  Viral  1997      M      5

# %%
myname.plot.barh(x='Year', y='Count')
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
crime = pd.read_csv('./Exercise Files/crime_boston.csv')

# %%
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I192064813          3006               Medical Assistance
# 1      I192064810          3410                            Towed
# 2      I192064808          2003  Offenses Against Child / Family
# 3      I192064803           802                   Simple Assault
# 4      I192064800          3114             Investigate Property
#
#                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0    SICK/INJURED/MEDICAL - PERSON      D14            794      NaN
# 1              TOWED MOTOR VEHICLE       B3            435      NaN
# 2  CHILD ENDANGERMENT (NO ASSAULT)      C11            355      NaN
# 3         ASSAULT SIMPLE - BATTERY      E18            554      NaN
# 4             INVESTIGATE PROPERTY      E18            502      NaN
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0  2019-08-17 21:00:00  2019      8    Saturday    21  Part Three
# ...

# %%
crime.groupby("INCIDENT_NUMBER").count()
# Out:
#                  OFFENSE_CODE  OFFENSE_CODE_GROUP  OFFENSE_DESCRIPTION  \
# INCIDENT_NUMBER
# I010370257-00               1                   1                    1
# I020662996-00               1                   1                    1
# I020669075-00               1                   1                    1
# I020674147-00               1                   1                    1
# I020691165-00               1                   1                    1
# ...                       ...                 ...                  ...
# I192064800                  1                   1                    1
# I192064803                  1                   1                    1
# I192064808                  1                   1                    1
# I192064810                  1                   1                    1
# I192064813                  1                   1                    1
#
#                  DISTRICT  REPORTING_AREA  SHOOTING  OCCURRED_ON_DATE  YEAR  \
# INCIDENT_NUMBER
# ...

# %%
crime.isnull()
# Out:
#         INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0                 False         False               False
# 1                 False         False               False
# 2                 False         False               False
# 3                 False         False               False
# 4                 False         False               False
# ...                 ...           ...                 ...
# 413667            False         False               False
# 413668            False         False               False
# 413669            False         False               False
# 413670            False         False               False
# 413671            False         False               False
#
#         OFFENSE_DESCRIPTION  DISTRICT  REPORTING_AREA  SHOOTING  \
# 0                     False     False           False      True
# 1                     False     False           False      True
# 2                     False     False           False      True
# ...

# %%
crime.isnull().any(axis=1)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 413667    True
# 413668    True
# 413669    True
# 413670    True
# 413671    True
# Length: 413672, dtype: bool

# %%
rows_with_missing_vals = crime.isnull().any(axis=1)

# %%
rows_with_missing_vals
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 413667    True
# 413668    True
# 413669    True
# 413670    True
# 413671    True
# Length: 413672, dtype: bool

# %%
crime_cleand = crime.drop(columns=['YEAR','MONTH','HOUR'])

# %%
crime_cleand['OFFENSE_CODE_GROUP'].unique()
# Out:
# array(['Medical Assistance', 'Towed', 'Offenses Against Child / Family',
#        'Simple Assault', 'Investigate Property', 'Verbal Disputes',
#        'Larceny', 'Fire Related Reports', 'Missing Person Reported',
#        'Robbery', 'Firearm Violations', 'Residential Burglary',
#        'Investigate Person', 'Drug Violation', 'Aggravated Assault',
#        'Violations', 'Motor Vehicle Accident Response', 'Property Found',
#        'Larceny From Motor Vehicle', 'Liquor Violation', 'Other',
#        'Harassment', 'Vandalism', 'Property Lost',
#        'Assembly or Gathering Violations', 'Warrant Arrests',
#        'Landlord/Tenant Disputes', 'Restraining Order Violations',
#        'Recovered Stolen Property', 'Auto Theft Recovery',
#        'Firearm Discovery', 'Other Burglary', 'Auto Theft',
#        'Commercial Burglary', 'Service', 'Police Service Incidents',
#        'Disorderly Conduct', 'Property Related Damage',
#        'Harbor Related Incidents', 'Fraud', 'Ballistics',
# ...

# %%
crime_cleand['DAY_OF_WEEK'].unique()
# Out:
# array(['Saturday', 'Friday', 'Wednesday', 'Thursday', 'Monday', 'Tuesday',
#        'Sunday'], dtype=object)

# %%
crime_cleand = crime_cleand.drop(columns='Location')

# %%
crime_cleand.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I192064813          3006               Medical Assistance
# 1      I192064810          3410                            Towed
# 2      I192064808          2003  Offenses Against Child / Family
# 3      I192064803           802                   Simple Assault
# 4      I192064800          3114             Investigate Property
#
#                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0    SICK/INJURED/MEDICAL - PERSON      D14            794      NaN
# 1              TOWED MOTOR VEHICLE       B3            435      NaN
# 2  CHILD ENDANGERMENT (NO ASSAULT)      C11            355      NaN
# 3         ASSAULT SIMPLE - BATTERY      E18            554      NaN
# 4             INVESTIGATE PROPERTY      E18            502      NaN
#
#       OCCURRED_ON_DATE DAY_OF_WEEK    UCR_PART            STREET        Lat  \
# 0  2019-08-17 21:00:00    Saturday  Part Three         QUINT AVE        NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
listing =  pd.read_csv('./Exercise Files/Airbnb_NYC_2019.csv')

# %%
listing
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sn.countplot(x='neighbourhood_group', data = listing)
plt.show()

# %%
sn.barplot(x='neighbourhood_group', y='price', data=listing)
plt.show()

# %%
sn.barplot(x='neighbourhood_group', y='price', data=listing, ci=False)
plt.show()

# %%
import numpy as np

# %%
listing
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
plt.hist(listing['price'])
plt.xlabel('Price (in USD)')
plt.show()

# %%
plt.hist(listing['price'], bins=np.arange(0,1500, 40))
plt.show()

# %%
plt.scatter(x=listing['price'], y=listing['number_of_reviews'])
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.show()

# %%
plt.scatter(x=listing['price'], y=listing['number_of_reviews'])
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.xlim(0, 1200)
plt.show()

# %%
plt.scatter(x=listing['price'], y=listing['number_of_reviews'], s=5)
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.xlim(0, 1200)
plt.show()
